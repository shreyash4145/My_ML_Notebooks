# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("Heart.csv")
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
# 5           6   56    1    nontypical     120   236    0        0    178
# 6           7   62    0  asymptomatic     140   268    0        2    160
# 7           8   57    0  asymptomatic     120   354    0        0    163
# 8           9   63    1  asymptomatic     130   254    0        2    147
# 9          10   53    1  asymptomatic     140   203    1        2    155
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# ...

# %%
df.tail(2)
# Out:
#      Unnamed: 0  Age  Sex   ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 301         302   57    0  nontypical     130   236    0        2    174
# 302         303   38    1  nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca    Thal  AHD
# 301      0      0.0      2  1.0  normal  Yes
# 302      0      0.0      1  NaN  normal   No

# %%
df.shape
# Out:
# (303, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df['Age']
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: Age, Length: 303, dtype: int64

# %%
df['Age'].shape
# Out:
# (303,)

# %%
df[['Age','Sex','Chol']]
# Out:
#      Age  Sex  Chol
# 0     63    1   233
# 1     67    1   286
# 2     67    1   229
# 3     37    1   250
# 4     41    0   204
# ..   ...  ...   ...
# 298   45    1   264
# 299   68    1   193
# 300   57    1   131
# 301   57    0   236
# 302   38    1   175
#
# [303 rows x 3 columns]

# %%
type(df[['Age','Sex','Chol']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Age','Sex','Chol']].shape
# Out:
# (303, 3)

# %%
df.iloc[0]
# Out:
# Unnamed: 0          1
# Age                63
# Sex                 1
# ChestPain     typical
# RestBP            145
# Chol              233
# Fbs                 1
# RestECG             2
# MaxHR             150
# ExAng               0
# Oldpeak           2.3
# Slope               3
# Ca                0.0
# Thal            fixed
# AHD                No
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes

# %%
type(df.iloc[0:3])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0:3].shape
# Out:
# (3, 15)

# %%
df.iloc[0:11:2]
# Out:
#     Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0            1   63    1       typical     145   233    1        2    150
# 2            3   67    1  asymptomatic     120   229    0        2    129
# 4            5   41    0    nontypical     130   204    0        2    172
# 6            7   62    0  asymptomatic     140   268    0        2    160
# 8            9   63    1  asymptomatic     130   254    0        2    147
# 10          11   57    1  asymptomatic     140   192    0        0    148
#
#     ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0       0      2.3      3  0.0       fixed   No
# 2       1      2.6      2  2.0  reversable  Yes
# 4       0      1.4      1  0.0      normal   No
# 6       0      3.6      3  2.0      normal  Yes
# 8       0      1.4      2  1.0  reversable  Yes
# 10      0      0.4      2  0.0       fixed   No

# %%
df.iloc[:,[4,5,10]]
# Out:
#      RestBP  Chol  Oldpeak
# 0       145   233      2.3
# 1       160   286      1.5
# 2       120   229      2.6
# 3       130   250      3.5
# 4       130   204      1.4
# ..      ...   ...      ...
# 298     110   264      1.2
# 299     144   193      3.4
# 300     130   131      1.2
# 301     130   236      0.0
# 302     138   175      0.0
#
# [303 rows x 3 columns]

# %%
df['ChestPain']=='asymptomatic'
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 298    False
# 299     True
# 300     True
# 301    False
# 302    False
# Name: ChestPain, Length: 303, dtype: bool

# %%
mask=df['ChestPain']=='asymptomatic'
df[mask]
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 6             7   62    0  asymptomatic     140   268    0        2    160
# 7             8   57    0  asymptomatic     120   354    0        0    163
# 8             9   63    1  asymptomatic     130   254    0        2    147
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 294         295   63    0  asymptomatic     124   197    0        0    136
# 296         297   59    1  asymptomatic     164   176    1        2     90
# 297         298   57    0  asymptomatic     140   241    0        0    123
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df[mask].shape
# Out:
# (144, 15)

# %%
def get_ChestPain_count(ChestPain):
    mask=df['ChestPain']==ChestPain
    return df[mask].shape[0]

# %%
get_ChestPain_count('nontypical')
# Out:
# 50

# %%
mask1=df['ChestPain']=='asymptomatic'
mask2=df['Chol']>130


df[mask1 & mask2]
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 6             7   62    0  asymptomatic     140   268    0        2    160
# 7             8   57    0  asymptomatic     120   354    0        0    163
# 8             9   63    1  asymptomatic     130   254    0        2    147
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 294         295   63    0  asymptomatic     124   197    0        0    136
# 296         297   59    1  asymptomatic     164   176    1        2     90
# 297         298   57    0  asymptomatic     140   241    0        0    123
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df[mask1 & mask2].shape[0]
# Out:
# 144

# %%
# value_count we use on categorical column
df['Thal'].value_counts()
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
import matplotlib.pyplot as plt


df['Thal'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Thal'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['AHD'].value_counts()
# Out:
# No     164
# Yes    139
# Name: AHD, dtype: int64

# %%
df['AHD'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='AHD'>

# %%
# Histogram used represent the numerical value 

df['Chol'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Series Operation
type(df['Thal'].value_counts())
# Out:
# pandas.core.series.Series

# %%
series1=df['Thal'].value_counts()
series1
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
series1.index
# Out:
# Index(['normal', 'reversable', 'fixed'], dtype='object')

# %%
series1.values
# Out:
# array([166, 117,  18], dtype=int64)

# %%
series1['fixed']
# Out:
# 18

# %%
df['Age'].value_counts()
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 60    12
# 51    12
# 56    11
# 62    11
# 44    11
# 64    10
# 41    10
# 67     9
# 63     9
# 42     8
# 43     8
# 45     8
# 53     8
# 55     8
# 61     8
# 65     8
# 50     7
# 66     7
# 48     7
# 46     7
# 47     5
# 49     5
# 70     4
# 68     4
# 35     4
# 39     4
# 69     3
# 71     3
# 40     3
# 34     2
# 37     2
# 38     2
# 29     1
# 77     1
# 74     1
# 76     1
# Name: Age, dtype: int64

# %%
df['Chol'].sort_values(ascending=False)
# Out:
# 152    564
# 48     417
# 181    409
# 121    407
# 173    394
#       ...
# 273    149
# 232    149
# 93     141
# 300    131
# 202    126
# Name: Chol, Length: 303, dtype: int64

# %%
df.sort_values('ChestPain')
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 151         152   42    0  asymptomatic     102   265    0        2    122
# 223         224   53    1  asymptomatic     123   282    0        0     95
# 106         107   59    1  asymptomatic     140   177    0        0    162
# 108         109   61    1  asymptomatic     120   260    0        0    140
# 109         110   39    1  asymptomatic     118   219    0        0    140
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 101         102   34    1       typical     118   182    0        2    174
# 262         263   60    0       typical     150   240    0        0    171
# 59           60   51    1       typical     125   213    0        2    125
# 199         200   59    1       typical     160   273    0        2    125
# 0             1   63    1       typical     145   233    1        2    150
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.sort_values('ChestPain',ascending=False)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 191         192   51    1  asymptomatic     140   298    0        0    122
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
# inplace will do perment changes in dataset 


df.sort_values('ChestPain',ascending=False, inplace=True)

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 191         192   51    1  asymptomatic     140   298    0        0    122
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.sort_values(['ChestPain','Age'])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 168         169   35    1  asymptomatic     126   282    0        2    156
# 117         118   35    0  asymptomatic     138   183    0        0    182
# 138         139   35    1  asymptomatic     120   198    0        0    130
# 109         110   39    1  asymptomatic     118   219    0        0    140
# 268         269   40    1  asymptomatic     152   223    0        0    181
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 275         276   64    1       typical     170   227    0        2    155
# 124         125   65    1       typical     138   282    1        2    174
# 27           28   66    0       typical     150   226    0        0    114
# 30           31   69    0       typical     140   239    0        0    151
# 196         197   69    1       typical     160   234    1        2    131
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.sort_values(['ChestPain','Age'],ascending=[True,False])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 161         162   77    1  asymptomatic     125   304    0        2    162
# 273         274   71    0  asymptomatic     112   149    0        0    125
# 155         156   70    1  asymptomatic     130   322    0        2    109
# 136         137   70    1  asymptomatic     145   174    0        0    125
# 299         300   68    1  asymptomatic     144   193    1        0    141
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 182         183   42    1       typical     148   244    0        2    178
# 41           42   40    1       typical     140   199    0        0    178
# 211         212   38    1       typical     120   231    0        0    182
# 101         102   34    1       typical     118   182    0        2    174
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
# drop_duplicates() method

df.drop_duplicates(subset=['ChestPain'])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 185         186   63    0    nontypical     140   195    0        0    179
# 290         291   67    1    nonanginal     152   212    0        2    150
# 44           45   61    0  asymptomatic     130   330    0        2    169
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 185      0      0.0      1  2.0      normal   No
# 290      0      0.8      2  0.0  reversable  Yes
# 44       0      0.0      1  0.0      normal  Yes

# %%
df.drop_duplicates(subset=['ChestPain']).shape
# Out:
# (4, 15)

# %%
df.drop_duplicates(subset=['MaxHR'])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 64           65   54    1  asymptomatic     120   188    0        0    113
# 175         176   57    1  asymptomatic     152   274    0        0     88
# 74           75   44    1  asymptomatic     110   197    0        2    177
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 193         194   62    0  asymptomatic     138   294    1        0    106
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.drop_duplicates(subset=['RestBP','MaxHR'])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 191         192   51    1  asymptomatic     140   298    0        0    122
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.drop_duplicates(subset=['RestBP','MaxHR']).shape
# Out:
# (269, 15)

# %%
df.drop_duplicates('ChestPain',keep='last')[['ChestPain','AHD']].sort_values('ChestPain')
# Out:
#         ChestPain  AHD
# 151  asymptomatic   No
# 114    nonanginal  Yes
# 53     nontypical   No
# 298       typical  Yes

# %%
df.head(5)
# Out:
#      Unnamed: 0  Age  Sex ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0             1   63    1   typical     145   233    1        2    150      0
# 20           21   64    1   typical     110   211    0        2    144      1
# 275         276   64    1   typical     170   227    0        2    155      0
# 274         275   59    1   typical     134   204    0        0    162      0
# 27           28   66    0   typical     150   226    0        0    114      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# 20       1.8      2  0.0      normal   No
# 275      0.6      2  0.0  reversable   No
# 274      0.8      1  2.0      normal  Yes
# 27       2.6      3  0.0      normal   No

# %%
df.pivot_table(index=['ChestPain','Sex'], columns='RestBP', values='Chol')
# Out:
# RestBP              94     100    101    102    104    105    106    108  \
# ChestPain    Sex
# asymptomatic 0      NaN  248.0    NaN  265.0    NaN    NaN  223.0  269.0
#              1      NaN  266.5    NaN    NaN  208.0    NaN    NaN  233.0
# nonanginal   0    199.0    NaN    NaN  318.0    NaN    NaN    NaN  204.0
#              1    227.0  222.0    NaN    NaN    NaN  240.0    NaN  243.0
# nontypical   0      NaN    NaN    NaN    NaN    NaN  201.0    NaN    NaN
#              1      NaN    NaN  197.0    NaN    NaN    NaN    NaN  309.0
# typical      0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#              1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# RestBP                   110    112  ...         160    164    165    170  \
# ChestPain    Sex                     ...
# asymptomatic 0    254.000000  149.0  ...  164.000000    NaN    NaN  225.0
#              1    226.363636  234.0  ...  267.666667  176.0  289.0  326.0
# ...

# %%
df.corr()
# Out:
#             Unnamed: 0       Age       Sex    RestBP      Chol       Fbs  \
# Unnamed: 0    1.000000 -0.002367 -0.070849 -0.022028 -0.095518 -0.039471
# Age          -0.002367  1.000000 -0.097542  0.284946  0.208950  0.118530
# Sex          -0.070849 -0.097542  1.000000 -0.064456 -0.199915  0.047862
# RestBP       -0.022028  0.284946 -0.064456  1.000000  0.130120  0.175340
# Chol         -0.095518  0.208950 -0.199915  0.130120  1.000000  0.009841
# Fbs          -0.039471  0.118530  0.047862  0.175340  0.009841  1.000000
# RestECG      -0.150232  0.148868  0.021647  0.146560  0.171043  0.069564
# MaxHR        -0.105488 -0.393806 -0.048663 -0.045351 -0.003432 -0.007854
# ExAng        -0.000402  0.091661  0.146201  0.064762  0.061310  0.025665
# Oldpeak      -0.120384  0.203805  0.102173  0.189171  0.046564  0.005747
# Slope        -0.028458  0.161770  0.037533  0.117382 -0.004062  0.059894
# Ca            0.046938  0.362605  0.093185  0.098773  0.119000  0.145478
#
# ...

# %%
import seaborn as sns

sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.rename(columns={'Age':'AGE','Unnamed: 0':'SRN'})
#df.rename(columns={'Age':'AGE','Unnamed: 0':'SRN'},inplace=True)
# Out:
#      SRN  AGE  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0      1   63    1       typical     145   233    1        2    150      0
# 20    21   64    1       typical     110   211    0        2    144      1
# 275  276   64    1       typical     170   227    0        2    155      0
# 274  275   59    1       typical     134   204    0        0    162      0
# 27    28   66    0       typical     150   226    0        0    114      0
# ..   ...  ...  ...           ...     ...   ...  ...      ...    ...    ...
# 72    73   62    1  asymptomatic     120   267    0        0     99      1
# 191  192   51    1  asymptomatic     140   298    0        0    122      1
# 192  193   43    1  asymptomatic     132   247    1        2    143      1
# 193  194   62    0  asymptomatic     138   294    1        0    106      0
# 151  152   42    0  asymptomatic     102   265    0        2    122      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.set_index('Unnamed: 0')
# Out:
#             Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# Unnamed: 0
# 1            63    1       typical     145   233    1        2    150      0
# 21           64    1       typical     110   211    0        2    144      1
# 276          64    1       typical     170   227    0        2    155      0
# 275          59    1       typical     134   204    0        0    162      0
# 28           66    0       typical     150   226    0        0    114      0
# ...         ...  ...           ...     ...   ...  ...      ...    ...    ...
# 73           62    1  asymptomatic     120   267    0        0     99      1
# 192          51    1  asymptomatic     140   298    0        0    122      1
# 193          43    1  asymptomatic     132   247    1        2    143      1
# 194          62    0  asymptomatic     138   294    1        0    106      0
# 152          42    0  asymptomatic     102   265    0        2    122      0
#
# ...

# %%
# Dropping Missing Data using dropna()
# how will drop when all column values are NA
df.dropna(how='all').shape
# Out:
# (303, 15)

# %%
# Column Operation NA 
df.dropna(axis=1)

df.dropna(axis=1, how='all')
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 191         192   51    1  asymptomatic     140   298    0        0    122
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope  AHD
# 0        0      2.3      3   No
# ...

# %%
df.dropna(subset=['Age'])
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 191         192   51    1  asymptomatic     140   298    0        0    122
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
# Filling missing values using fillna() method

df.fillna(0)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 20           21   64    1       typical     110   211    0        2    144
# 275         276   64    1       typical     170   227    0        2    155
# 274         275   59    1       typical     134   204    0        0    162
# 27           28   66    0       typical     150   226    0        0    114
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 72           73   62    1  asymptomatic     120   267    0        0     99
# 191         192   51    1  asymptomatic     140   298    0        0    122
# 192         193   43    1  asymptomatic     132   247    1        2    143
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df['Sex'].fillna("not Specified")
# Out:
# 0      1
# 20     1
# 275    1
# 274    1
# 27     0
#       ..
# 72     1
# 191    1
# 192    1
# 193    0
# 151    0
# Name: Sex, Length: 303, dtype: int64

# %%
df['Age'].fillna()
